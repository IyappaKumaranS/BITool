# %%
pip install duckdb
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: C:\Users\Asus\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import duckdb

con = duckdb.connect()
con.sql("SELECT 42 AS x").show()
# Out:
# ┌───────┐
# │   x   │
# │ int32 │
# ├───────┤
# │    42 │
# └───────┘

# %%
duckdb
# Out:
# <module 'duckdb' from 'C:\\Users\\Asus\\AppData\\Local\\Packages\\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\\LocalCache\\local-packages\\Python312\\site-packages\\duckdb\\__init__.py'>

# %%
import pandas as pd

# %%
data = pd.read_csv("S:\BI_Tool\healthcare_dataset.csv")
data
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_17612\2803457486.py:1: SyntaxWarning: invalid escape sequence '\B'
#   data = pd.read_csv("S:\BI_Tool\healthcare_dataset.csv")
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# ...

# %%
duckdb.read_csv("S:\BI_Tool\healthcare_dataset.csv")
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# <>:1: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\Asus\AppData\Local\Temp\ipykernel_17612\996236881.py:1: SyntaxWarning: invalid escape sequence '\B'
#   duckdb.read_csv("S:\BI_Tool\healthcare_dataset.csv")
# ┌────────────────────┬───────┬─────────┬────────────┬───────────────────┬───────────────────┬──────────────────────┬───────────────────────────────┬────────────────────┬────────────────────┬─────────────┬────────────────┬────────────────┬─────────────┬──────────────┐
# │        Name        │  Age  │ Gender  │ Blood Type │ Medical Condition │ Date of Admission │        Doctor        │           Hospital            │ Insurance Provider │   Billing Amount   │ Room Number │ Admission Type │ Discharge Date │ Medication  │ Test Results │
# ...

# %%
con = duckdb.connect(database="healthcare.duckdb")

con.execute("""
CREATE TABLE healthcare AS
SELECT * FROM read_csv_auto(
    'S:/BI_Tool/healthcare_dataset.csv'
)
""")

# %%
con.execute("DESCRIBE healthcare").fetchdf()
# Out:
#            column_name column_type null   key default extra
# 0                 Name     VARCHAR  YES  None    None  None
# 1                  Age      BIGINT  YES  None    None  None
# 2               Gender     VARCHAR  YES  None    None  None
# 3           Blood Type     VARCHAR  YES  None    None  None
# 4    Medical Condition     VARCHAR  YES  None    None  None
# 5    Date of Admission        DATE  YES  None    None  None
# 6               Doctor     VARCHAR  YES  None    None  None
# 7             Hospital     VARCHAR  YES  None    None  None
# 8   Insurance Provider     VARCHAR  YES  None    None  None
# 9       Billing Amount      DOUBLE  YES  None    None  None
# 10         Room Number      BIGINT  YES  None    None  None
# 11      Admission Type     VARCHAR  YES  None    None  None
# 12      Discharge Date        DATE  YES  None    None  None
# 13          Medication     VARCHAR  YES  None    None  None
# 14        Test Results     VARCHAR  YES  None    None  None

# %%
con.execute("SELECT COUNT(*) FROM healthcare").fetchone()
# Out:
# (55500,)

# %%
con.execute("SELECT COUNT(*) FROM healthcare").fetchone()
print("Iyappa Kumaran")
print("Commit from Another Branch")
print("Code Chanages for one line")
print("Code changees for second line")

# %%
con.execute("SELECT COUNT(*) FROM healthcare").fetchone()
print("Iyappa Kumaran")
print("Commit from Another Branch")
print("Code Chanages for one line")
print("Code changees for second line")
print("Code without stash")

# %%
print("Main Branch Code without stash")

# %%
print("Main Branch Code after stash")

# %%
con.execute("SELECT COUNT(*) FROM healthcare").fetchone()
con.execute("SELECT COUNT(*) FROM healthcare").fetchone()
print("Iyappa Kumaran")
print("Commit from Another Branch")
print("Code Chanages for one line")
print("Code changees for second line")

# %%
print("Stash Code before commit")
